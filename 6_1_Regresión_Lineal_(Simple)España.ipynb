# %% [markdown]
# # 6.1 Regresión Lineal (Simple) España
#
# ## Lucía Castañeda
# ## A01706644

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('Evaluación1_España.csv')
df.head(5)
# Out:
# <ipython-input-12-ac8903a36a0e>:1: DtypeWarning: Columns (0,1,3,10,36,45,46,54) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv('Evaluación1_España.csv')
#    0       id                           listing_url scrape_id last_scraped  \
# 0  0    14551    https://www.airbnb.com/rooms/14551  2.02E+13     31/03/23
# 1  1  1205757  https://www.airbnb.com/rooms/1205757  2.02E+13     31/03/23
# 2  2  1212820  https://www.airbnb.com/rooms/1212820  2.02E+13     01/04/23
# 3  3   751638   https://www.airbnb.com/rooms/751638  2.02E+13     31/03/23
# 4  4    41342    https://www.airbnb.com/rooms/41342  2.02E+13     01/04/23
#
#             source                                      name  \
# 0      city scrape  Cozy & Colorful by Nature (Private Room)
# 1      city scrape       HabitaciÃ³n doble + baÃ±o y terraza
# 2      city scrape       Apartment port de rei stunning wiew
# 3      city scrape       Room Limon - Casa Pati de lÂ´Albera
# 4  previous scrape         Beachfront Tamariua (Costa Brava)
#
#                                          description  \
# 0  Up in the hill of MontjuÃ¯c (a mountain overlo...
# 1  <b>The space</b><br />HabitaciÃ³n confortable ...
# 2  <b>The space</b><br />Apartments first line un...
# 3  <b>The space</b><br />Nice room with 2 individ...
# 4  A little paradise by the sea. Apartment 2/4 ad...
#
#                                neighborhood_overview  \
# 0  MontjuÃ¯c is most likely the best neighborhood...
# 1  Bonitas playas a 15 minutos en coche. Piscina ...
# 2                                                  0
# 3  Sant Climent is a tiny village, with a populat...
# 4  Apartment located outside the town on a small ...
#
#                                          picture_url  ...  \
# 0  https://a0.muscache.com/pictures/16209908/f1fe...  ...
# 1  https://a0.muscache.com/pictures/02e0a61e-078e...  ...
# 2  https://a0.muscache.com/pictures/18245529/0886...  ...
# 3  https://a0.muscache.com/pictures/64276178/98d1...  ...
# 4  https://a0.muscache.com/pictures/70414801/59d4...  ...
#
#   review_scores_communication review_scores_location review_scores_value  \
# 0                        4.91                   4.63                4.74
# 1                        4.91                   4.69                4.80
# 2                        4.76                   4.74                4.32
# 3                        5.00                   4.63                4.50
# 4                        4.73                   4.91                4.36
#
#        license instant_bookable calculated_host_listings_count  \
# 0  HUTG-049542                f                              1
# 1            0                f                              1
# 2            0                f                              2
# 3     PG000794                t                              6
# 4  HUTG-003688                f                              1
#
#   calculated_host_listings_count_entire_homes  \
# 0                                           0
# 1                                           0
# 2                                           2
# 3                                           1
# 4                                           1
#
#    calculated_host_listings_count_private_rooms  \
# 0                                             1
# 1                                             1
# 2                                             0
# 3                                             5
# 4                                             0
#
#    calculated_host_listings_count_shared_rooms reviews_per_month
# 0                                            0              0.37
# 1                                            0              0.51
# 2                                            0              0.62
# 3                                            0              0.08
# 4                                            0              0.09
#
# [5 rows x 76 columns]

# %%
# Seleccionar los tipos de habitaciones de interés
room_types = ["Entire home/apt", "Private room"]
data = df[df["room_type"].isin(room_types)]

# %% [markdown]
# “host_acceptance_rate vs host_response_rate”

# %%
from turtle import color


sns.scatterplot(x='host_response_rate', y='host_acceptance_rate', color="blue", data=data)
# Out:
# <Axes: xlabel='host_response_rate', ylabel='host_acceptance_rate'>

# %%
#Declaramos las variables dependientes e independientes para la regresión lineal

Vars_Indep= df[['host_response_rate']]
Var_Dep= df['host_acceptance_rate']

# %%
#Se define model como la función de regresión lineal
from sklearn.linear_model import LinearRegression
model= LinearRegression()

# %%
#Verificamos la función relacionada al modelo
type(model)
# Out:
# sklearn.linear_model._base.LinearRegression

# %%
#Ajustamos el modelo con las variables antes declaradas
model.fit(X=Vars_Indep, y=Var_Dep)
# Out:
# LinearRegression()

# %%
#Verificamos los coeficientes obtenidos para el modelo ajustado
model.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['host_response_rate'], dtype=object),
#  'n_features_in_': 1,
#  'coef_': array([0.47449743]),
#  'rank_': 1,
#  'singular_': array([4576.64638512]),
#  'intercept_': 44.244349839966446}

# %% [markdown]
# **Modelo matemático: y= 0.47449743 + 44.244349839966446**

# %%
# SI Corroboramos cual es el coeficiente de Determinación de nuestro modelo
coef_Deter=model.score(X=Vars_Indep, y=Var_Dep)
coef_Deter
# Out:
# 0.2872099167487018

# %%
# SI Corroboramos cual es el coeficiente de Correlación de nuestro modelo
coef_Correl=np.sqrt(coef_Deter)
coef_Correl
# Out:
# 0.5359196924434684

# %% [markdown]
# “host_acceptance_rate vs price”

# %%
from turtle import color


sns.scatterplot(x='price', y='host_acceptance_rate', color="blue", data=data)
# Out:
# <Axes: xlabel='price', ylabel='host_acceptance_rate'>

# %%
#Declaramos las variables dependientes e independientes para la regresión lineal

Vars_Indep= df[['price']]
Var_Dep= df['host_acceptance_rate']

# %%
#Se define model como la función de regresión lineal
from sklearn.linear_model import LinearRegression
model= LinearRegression()

# %%
#Verificamos la función relacionada al modelo
type(model)
# Out:
# sklearn.linear_model._base.LinearRegression

# %%
#Ajustamos el modelo con las variables antes declaradas
model.fit(X=Vars_Indep, y=Var_Dep)
# Out:
# LinearRegression()

# %%
#Verificamos los coeficientes obtenidos para el modelo ajustado
model.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['price'], dtype=object),
#  'n_features_in_': 1,
#  'coef_': array([-0.00208784]),
#  'rank_': 1,
#  'singular_': array([88020.14933494]),
#  'intercept_': 84.72633809907205}

# %% [markdown]
# **Modelo matemático: y= -0.00208784 + 84.72633809907205**

# %%
# SI Corroboramos cual es el coeficiente de Determinación de nuestro modelo
coef_Deter=model.score(X=Vars_Indep, y=Var_Dep)
coef_Deter
# Out:
# 0.0020568164568632863

# %%
# SI Corroboramos cual es el coeficiente de Correlación de nuestro modelo
coef_Correl=np.sqrt(coef_Deter)
coef_Correl
# Out:
# 0.04535213839350121

# %% [markdown]
# “host_acceptance_rate vs number_of_reviews ”

# %%
from turtle import color


sns.scatterplot(x='number_of_reviews', y='host_acceptance_rate', color="blue", data=data)
# Out:
# <Axes: xlabel='number_of_reviews', ylabel='host_acceptance_rate'>

# %%
#Declaramos las variables dependientes e independientes para la regresión lineal

Vars_Indep= df[['number_of_reviews']]
Var_Dep= df['host_acceptance_rate']

# %%
#Se define model como la función de regresión lineal
from sklearn.linear_model import LinearRegression
model= LinearRegression()

# %%
#Verificamos la función relacionada al modelo
type(model)
# Out:
# sklearn.linear_model._base.LinearRegression

# %%
#Ajustamos el modelo con las variables antes declaradas
model.fit(X=Vars_Indep, y=Var_Dep)
# Out:
# LinearRegression()

# %%
#Verificamos los coeficientes obtenidos para el modelo ajustado
model.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['number_of_reviews'], dtype=object),
#  'n_features_in_': 1,
#  'coef_': array([0.08033257]),
#  'rank_': 1,
#  'singular_': array([4880.94298329]),
#  'intercept_': 83.05004392000639}

# %% [markdown]
# **Modelo matemático: y= 0.08033257 + 83.05004392000639**

# %%
# SI Corroboramos cual es el coeficiente de Determinación de nuestro modelo
coef_Deter=model.score(X=Vars_Indep, y=Var_Dep)
coef_Deter
# Out:
# 0.009363275966000728

# %%
# SI Corroboramos cual es el coeficiente de Correlación de nuestro modelo
coef_Correl=np.sqrt(coef_Deter)
coef_Correl
# Out:
# 0.09676402206399198

# %% [markdown]
# “review_scores_location vs review_scores_cleanliness”

# %%
from turtle import color


sns.scatterplot(x='review_scores_cleanliness', y='review_scores_location', color="blue", data=data)
# Out:
# <Axes: xlabel='review_scores_cleanliness', ylabel='review_scores_location'>

# %%
#Declaramos las variables dependientes e independientes para la regresión lineal

Vars_Indep= df[['review_scores_cleanliness']]
Var_Dep= df['review_scores_location']

# %%
#Se define model como la función de regresión lineal
from sklearn.linear_model import LinearRegression
model= LinearRegression()

# %%
#Verificamos la función relacionada al modelo
type(model)
# Out:
# sklearn.linear_model._base.LinearRegression

# %%
#Ajustamos el modelo con las variables antes declaradas
model.fit(X=Vars_Indep, y=Var_Dep)
# Out:
# LinearRegression()

# %%
#Verificamos los coeficientes obtenidos para el modelo ajustado
model.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['review_scores_cleanliness'], dtype=object),
#  'n_features_in_': 1,
#  'coef_': array([0.29992924]),
#  'rank_': 1,
#  'singular_': array([70.49724371]),
#  'intercept_': 3.3562817298958274}

# %% [markdown]
# **Modelo matemático: y= 0.29992924 + 3.3562817298958274**

# %%
# SI Corroboramos cual es el coeficiente de Determinación de nuestro modelo
coef_Deter=model.score(X=Vars_Indep, y=Var_Dep)
coef_Deter
# Out:
# 0.1699147152492273

# %%
# SI Corroboramos cual es el coeficiente de Correlación de nuestro modelo
coef_Correl=np.sqrt(coef_Deter)
coef_Correl
# Out:
# 0.41220712663566034

# %% [markdown]
# “availability_365 vs number_of_reviews”

# %%
from turtle import color


sns.scatterplot(x='number_of_reviews', y='availability_365', color="blue", data=data)
# Out:
# <Axes: xlabel='number_of_reviews', ylabel='availability_365'>

# %%
#Declaramos las variables dependientes e independientes para la regresión lineal
Vars_Indep= df[['number_of_reviews']]
Var_Dep= df['availability_365']

# %%
#Se define model como la función de regresión lineal
from sklearn.linear_model import LinearRegression
model= LinearRegression()

# %%
#Verificamos la función relacionada al modelo
type(model)
# Out:
# sklearn.linear_model._base.LinearRegression

# %%
#Ajustamos el modelo con las variables antes declaradas
model.fit(X=Vars_Indep, y=Var_Dep)
# Out:
# LinearRegression()

# %%
#Verificamos los coeficientes obtenidos para el modelo ajustado
model.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['number_of_reviews'], dtype=object),
#  'n_features_in_': 1,
#  'coef_': array([0.18048568]),
#  'rank_': 1,
#  'singular_': array([4880.94298329]),
#  'intercept_': 188.94368689696915}

# %% [markdown]
# **Modelo matemático: y= 0.18048568 + 188.94368689696915**

# %%
# SI Corroboramos cual es el coeficiente de Determinación de nuestro modelo
coef_Deter=model.score(X=Vars_Indep, y=Var_Dep)
coef_Deter
# Out:
# 0.003121996475983879

# %%
# SI Corroboramos cual es el coeficiente de Correlación de nuestro modelo
coef_Correl=np.sqrt(coef_Deter)
coef_Correl
# Out:
# 0.05587482864388829

# %% [markdown]
# “reviews_per_month vs review_scores_communication”

# %%
from turtle import color


sns.scatterplot(x='review_scores_communication', y='reviews_per_month', color="blue", data=data)
# Out:
# <Axes: xlabel='review_scores_communication', ylabel='reviews_per_month'>

# %%
#Declaramos las variables dependientes e independientes para la regresión lineal
Vars_Indep= df[['review_scores_communication']]
Var_Dep= df['reviews_per_month']

# %%
#Se define model como la función de regresión lineal
from sklearn.linear_model import LinearRegression
model= LinearRegression()

# %%
#Verificamos la función relacionada al modelo
type(model)
# Out:
# sklearn.linear_model._base.LinearRegression

# %%
#Ajustamos el modelo con las variables antes declaradas
model.fit(X=Vars_Indep, y=Var_Dep)
# Out:
# LinearRegression()

# %%
#Verificamos los coeficientes obtenidos para el modelo ajustado
model.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['review_scores_communication'], dtype=object),
#  'n_features_in_': 1,
#  'coef_': array([0.19846639]),
#  'rank_': 1,
#  'singular_': array([61.53941807]),
#  'intercept_': -0.4176639688109778}

# %% [markdown]
# **Modelo matemático: y= 0.19846639 + -0.4176639688109778**

# %%
# SI Corroboramos cual es el coeficiente de Determinación de nuestro modelo
coef_Deter=model.score(X=Vars_Indep, y=Var_Dep)
coef_Deter
# Out:
# 0.01817080740289101

# %%
# SI Corroboramos cual es el coeficiente de Correlación de nuestro modelo
coef_Correl=np.sqrt(coef_Deter)
coef_Correl
# Out:
# 0.13479913724831852

# %%
# Seleccionar los tipos de habitaciones y las variables de interés
room_types = ["Entire home/apt", "Private room"]
variables = ["host_acceptance_rate", "host_response_rate",
             "review_scores_location", "review_scores_cleanliness",
             "price", "availability_365", "number_of_reviews",
             "reviews_per_month", "review_scores_communication"]

# Crear una tabla para almacenar los coeficientes de determinación y correlación
results = pd.DataFrame(columns=["room_type", "variable", "r2", "corr"])

# Calcular los coeficientes de determinación y correlación para todas las combinaciones posibles
for room_type in room_types:
    for variable in variables:
        # Seleccionar los datos correspondientes al tipo de habitación y la variable de interés
        data_subset = data[data["room_type"] == room_type][[variable, "number_of_reviews"]].dropna()
        
        # Crear el modelo de regresión lineal y calcular los coeficientes de determinación y correlación
        if len(data_subset) > 0:
            X = data_subset[variable].values.reshape(-1, 1)
            y = data_subset["number_of_reviews"].values.reshape(-1, 1)
            model = LinearRegression().fit(X, y)
            r2 = model.score(X, y)
            corr = data_subset.corr().iloc[0,1]
            
            # Agregar los resultados a la tabla
            results = results.append({"room_type": room_type, "variable": variable, "r2": r2, "corr": corr}, ignore_index=True)

# Imprimir la tabla de resultados
print(results)
# Out:
# <ipython-input-62-313d3d3b3522>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append({"room_type": room_type, "variable": variable, "r2": r2, "corr": corr}, ignore_index=True)
# <ipython-input-62-313d3d3b3522>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append({"room_type": room_type, "variable": variable, "r2": r2, "corr": corr}, ignore_index=True)
# <ipython-input-62-313d3d3b3522>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append({"room_type": room_type, "variable": variable, "r2": r2, "corr": corr}, ignore_index=True)
# <ipython-input-62-313d3d3b3522>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append({"room_type": room_type, "variable": variable, "r2": r2, "corr": corr}, ignore_index=True)
# <ipython-input-62-313d3d3b3522>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append({"room_type": room_type, "variable": variable, "r2": r2, "corr": corr}, ignore_index=True)
# <ipython-input-62-313d3d3b3522>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append({"room_type": room_type, "variable": variable, "r2": r2, "corr": corr}, ignore_index=True)
#           room_type                     variable        r2      corr
# 0   Entire home/apt         host_acceptance_rate  0.008921  0.094449
# 1   Entire home/apt           host_response_rate  0.007960  0.089218
# 2   Entire home/apt       review_scores_location  0.010882  0.104316
# 3   Entire home/apt    review_scores_cleanliness  0.022249  0.149160
# 4   Entire home/apt                        price  0.003226 -0.056794
# 5   Entire home/apt             availability_365  0.003583  0.059860
# 6   Entire home/apt            number_of_reviews  1.000000  1.000000
# 7   Entire home/apt            reviews_per_month  0.441237  0.664257
# 8   Entire home/apt  review_scores_communication  0.017222  0.131231
# 9      Private room         host_acceptance_rate  0.023164  0.152198
# 10     Private room           host_response_rate  0.037528  0.193721
# 11     Private room       review_scores_location  0.005565  0.074599
# 12     Private room    review_scores_cleanliness  0.023985  0.154869
# 13     Private room                        price  0.007580 -0.087062
# 14     Private room             availability_365  0.000003  0.001864
# 15     Private room            number_of_reviews  1.000000  1.000000
# 16     Private room            reviews_per_month  0.591462  0.769066
# 17     Private room  review_scores_communication  0.017932  0.133911
# <ipython-input-62-313d3d3b3522>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append({"room_type": room_type, "variable": variable, "r2": r2, "corr": corr}, ignore_index=True)
# <ipython-input-62-313d3d3b3522>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append({"room_type": room_type, "variable": variable, "r2": r2, "corr": corr}, ignore_index=True)
# <ipython-input-62-313d3d3b3522>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append({"room_type": room_type, "variable": variable, "r2": r2, "corr": corr}, ignore_index=True)
# <ipython-input-62-313d3d3b3522>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append({"room_type": room_type, "variable": variable, "r2": r2, "corr": corr}, ignore_index=True)
# <ipython-input-62-313d3d3b3522>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append({"room_type": room_type, "variable": variable, "r2": r2, "corr": corr}, ignore_index=True)
# <ipython-input-62-313d3d3b3522>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append({"room_type": room_type, "variable": variable, "r2": r2, "corr": corr}, ignore_index=True)
# <ipython-input-62-313d3d3b3522>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append({"room_type": room_type, "variable": variable, "r2": r2, "corr": corr}, ignore_index=True)
# <ipython-input-62-313d3d3b3522>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append({"room_type": room_type, "variable": variable, "r2": r2, "corr": corr}, ignore_index=True)
# <ipython-input-62-313d3d3b3522>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append({"room_type": room_type, "variable": variable, "r2": r2, "corr": corr}, ignore_index=True)
# <ipython-input-62-313d3d3b3522>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append({"room_type": room_type, "variable": variable, "r2": r2, "corr": corr}, ignore_index=True)
# <ipython-input-62-313d3d3b3522>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append({"room_type": room_type, "variable": variable, "r2": r2, "corr": corr}, ignore_index=True)
# <ipython-input-62-313d3d3b3522>:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append({"room_type": room_type, "variable": variable, "r2": r2, "corr": corr}, ignore_index=True)
